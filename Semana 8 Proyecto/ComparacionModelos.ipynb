# %%
import matplotlib.pyplot as plt

# Datos de BLEU Scores por modelo
bleu_scores = {
    "ResNet50": [0.363395, 0.215636, 0.140402, 0.092832],
    "VGG16_e30_b64": [0.501170, 0.372547, 0.294499, 0.237009],
    "InceptionV3": [0.277302, 0.143201, 0.083901, 0.053432],
    "VGG16_model_e20_b64_lr1e-03": [0.3970, 0.2594, 0.1739, 0.1156],
    "VGG16_model_e10_b64_lr5e-05": [0.2785, 0.1136, 0.0284, 0.0000],
    "VGG16_model_e10_b64_lr1e-03": [0.3016, 0.1821, 0.1080, 0.0619],
    "VGG16_model_e20_b64_lr1e-03" : [ 0.3970,0.2594 , 0.1739, 0.1156],
    "VGG16_model_e20_b64_lr5e-05" : [ 0.4063, 0.2507,0.1391, 0.0716]
}


bleu_levels = ["BLEU-1", "BLEU-2", "BLEU-3", "BLEU-4"]

# Crear la gráfica
plt.figure(figsize=(10, 6))
for model, scores in bleu_scores.items():
    plt.plot(bleu_levels, scores, marker='o', label=model)

plt.title("BLEU Scores por Modelo")
plt.xlabel("N-Gram (BLEU)")
plt.ylabel("BLEU Score")
plt.ylim(0, 0.6)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
