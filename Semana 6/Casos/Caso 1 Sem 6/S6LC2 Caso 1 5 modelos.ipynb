# %% [markdown]
# ![banner.png](attachment:banner.png)

# %% [markdown]
# # Aplicaciones de Redes Convolucionales - Semana 6
# ## _Transfer Learning_ para nuevas tareas usando redes pre-entrenadas en Keras
# ### Laboratorio Sumativo
#
# ### Propósito de la actividad
# En esta actividad mostraremos cómo usar redes convolucionales para visión computacional que ya han sido pre-entrenadas con grandes cantidades de datos, pero que quieren ser usadas con unos nuevos datos y para una tarea diferente.
#
# Esto corresponde a la aplicación de _transfer learning_, en donde se remueven las últimas capas de una red pre-entrenada, y después de ponen nuevas capas entrenables adicionales. En _Keras_ este proceso también se conoce como _fine tunning_.
#
# Otra opción, que es muy parecida al _transfer learning_ es usar capas intermedias de una red pre-entrenada y calcular las variables transformadas hasta esta capa. Estas variables, se pueden convertir en una nueva muestra de entrenamiento para un modelo de _machine learning_. En _Keras_ este proceso se conoce como _feature extraction_.
#
#
# ### Instrucciones generales
#
# El laboratorio contiene dos partes, la primera (A) consiste en la explicación de _transfer learning_ usando la red VGG16, y la segunda (B) corresponde a la asignación del laboratorio sumativo.
#
# Para la segunda parte, debe realizar la entrega correspondiente con la solución.
#
# ### Librerías a importar
#
# A continuación se muestran los comandos a ejecutar para poder implementar los procedimientos de este notebook:

# %%
import numpy as np
import matplotlib.pyplot as plt
#Las siguientes dos líneas evitan la generación de "warnings" y "flags" al importar keras y tensorflow.
#Dichas advertencias no comprometen el funcionamiento del código.
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
#Importación de keras y tensorflow
import tensorflow as tf
#import tensorflow_datasets as tfds
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from keras.optimizers import Adam

# %%
# Función para graficar la historia del entrenamiento (preparada en talleres anteriores)
import matplotlib.pyplot as plt

def plot_history(history):
    """
    Plots training and validation loss and accuracy.

    Parameters:
      history: A dictionary containing keys:
          'loss', 'val_loss', 'accuracy', and 'val_accuracy'.
          (If a Keras History object is passed, its `.history` attribute will be used.)
    """
    hist = history.history if hasattr(history, 'history') else history

    # Final metrics
    print(f"Train Loss final: {hist['loss'][-1]:.3f}, "
          f"Train Accuracy final: {hist['accuracy'][-1]:.3f}")
    print(f"Validation Loss final: {hist['val_loss'][-1]:.3f}, "
          f"Validation Accuracy final: {hist['val_accuracy'][-1]:.3f}")

    plt.figure(figsize=(12, 5))

    # Loss plot
    plt.subplot(1, 2, 1)
    plt.plot(hist['loss'], label='Training Loss', marker='o')
    plt.plot(hist['val_loss'], label='Validation Loss', marker='o')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training vs. Validation Loss')
    plt.legend()
    plt.grid(True)

    # AUC plot
    plt.subplot(1, 2, 2)
    plt.plot(hist['accuracy'], label='Training Accuracy', marker='o')
    plt.plot(hist['val_accuracy'], label='Validation Accuracy', marker='o')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training vs. Validation Accuracy')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### A. Uso de _CNN_ pre-entrenada para Aprendizaje por Transferencia
#
# La estructura de modelo secuencial tipo CNN puede ser importada directamente sin necesidad de definir cada una de las capas, como conv2D, MaxPooling, etc. Muchas redes pueden ser implementadas automáticamente desde _Keras_ (https://keras.io/api/applications/). Sin embargo, muchas veces estas redes son bastante genéricas. Por ejemplo, muchas de ellas han sido entrenadas con los datos de _IMAGENET_ para clasificación multiclase, pero con alrededor de 1000 clases diferentes. Cuando requerimos un uso más específico, por ejemplo, reconocer la marca de un vehículo o el tipo de ambiente en una fotografía, este tipo de clasificación genérica no nos funciona muy bien.
#
# La opción más directa, es hacer nuestra propia red convolucional desde cero con nuestros propios datos. Para esto, podemos tomas como inspiración muchas de las arquitecturas que ya han sido probadas (AlexNet, VGG16, GoogleNEt, ResNet, etc.). Sin embargo, es posible que, dado que nuestros datos corresponden a una aplicación más especializada, no tengamos a nuestra disposición la cantidad suficiente de imágenes para entrenar nuestra red.
#
# Otra opción más útil, sería usar como base de nuestro modelo, una red ya pre-entrenada. Por ejemplo, las primeras capas de una red tipo ResNet. El principio de este enfoque, es que las primeras capas todavía no se han especilizado completamente y son bastante genéricas en términos de reconocer patrones básicos que pueden funcionar en diversos problemas. Para estas primeras capas tomamos los pesos (estimación de los parámetros) ya fijos (recordemos que tenemos la opción de definir el parámetro "weights"). Sobre estas capas, podemos adicionar unas nuevas capas (generalmente son del tipo completamente conectadas) y entrenar los pesos de estas con los datos que tenemos a disposición para nuestro problema.
#
# Dentro de la calibración de los modelos de _Transfer Learning_, aparecen entonces nuevos hiper-parámetros que son necesarios de calibrar, como el número de capas del modelo base ya preentrenado y el número de capas entrenables adicionales. Esto depende, por supuesto, de la cantidad de imágenes que tengamos disponibles y de la complejidad de la tarea.

# %% [markdown]
# #### _Transfer Learning_ en Keras usando VGG16
#
# La forma más sencilla de usar _transfer learning_ con redes pre-entrenadas, es cargando la red con los pesos fijos, como por ejemplo en el modelo VGG16, usando  `weights='imagenet'`, que incluye los valores de todos los parámetros ya entrenados con los datos descritos del ILSVRC. Sin embargo, en este caso el parámetro `include_top`, que hace referencia a si se incluyen las últimas 3 capas de tipo completamente conectadas (_fully connected_) se define como `False`, dado que se reemplazarán por capas nuevas.
#
# Además de esto, es necesario añadir las capas nuevas con las cuales crearemos nuestro modelo. Una vez se tiene la configuración del modelo, se fijan los valores de las primeras capas, haciendo para cada una de las _layers_ que no se entrenan `layer.trainable = False`.
#
# Miremos la implementación usando la red VGG16 contenida en _Keras Applications_:

# %%
#Importar modelo entrenado VGG16 con las últimas capas
#Puede tomar algunos segundos
vgg = VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %% [markdown]
# Sobre este modelo, el primer paso (que es opcional), es usar una operación de _pooling_ global sobre la salida de la última capa ("block5_pool"), para pasar a una arreglo en una dimensión de tamaño [1,1,512].

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

base=GlobalAveragePooling2D()(vgg.output)

# %% [markdown]
# Después, se pueden adicionar capas completamente conectadas ("Dense") de diferentes tamaños. En este caso, añadimos una capa de 256 nodos con activación RELU:

# %%
new=Dense(128,activation='relu')(base)

# %% [markdown]
# De la misma forma, es posible adicionar capas adicionales.
#
# Supongamos que el nuevo problema que queremos resolver es de reconocimiento de imágenes con 5 clases diferentes de objetos. Para esto, es necesario crear la capa de salida:

# %%
out_layer=Dense(5,activation='softmax')(new)

# %% [markdown]
# El último paso antes de compilar el modelo, es fijar las capas cuyos pesos queremos que se mantengan fijos, mientras que las capas restantes se dejan libres para entrenar. En este caso, todas las capas anteriores del VGG16 a las capas completamente conectadas se dejarán fijas:

# %%
for layer in vgg.layers:
    layer.trainable = False

# %% [markdown]
# Ahora se puede definir el nuevo modelo que va desde los _inputs_ del modelo base (VGG) hasta la capa de salida definida:

# %%
from tensorflow.keras.models import Model

model=Model(inputs=vgg.input,outputs=out_layer)

# %% [markdown]
# Y con esto, ya es posible compilar el modelo. En este caso usamos _Adam_ con un problema de clasificación multiclase. Puede ser definido a conveniencia para calibrar el modelo en términos de hiper-parámetros:

# %%
from keras.optimizers import Adam
model.compile(optimizer= Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.995), loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# %% [markdown]
# ***
# #### Problema de reconocimiento de imágenes y datos a usar
#
# En este caso, resolveremos un problema de identificación de especies de flores. Se tienen 5 diferentes especies que salen en los datos: daisy (margarita), dandelion (diente de león), roses (rosas), sunflowers (girasoles), y tulips (tulipanes). La base de datos contiene en total 3670 imágenes en color  y se obtiene directamente de un repositorio usando las herramientas de Tensorflow para carga de datos:

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
archive = tf.keras.utils.get_file(origin=dataset_url, extract=True)
data_dir = pathlib.Path(archive).with_suffix('')

# %%
print(data_dir)
# Out:
# C:\Users\WD\.keras\datasets\flower_photos

# %% [markdown]
# Miremos primero el número total de imágenes:

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %% [markdown]
# Y algunas imágenes de muestra:

# %%
import PIL
import PIL.Image
roses = list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %%
import PIL
import PIL.Image
roses = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(roses[4]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x214>

# %% [markdown]
# Ahora definimos los datos para entrenamiento y para validación (`train_ds` y `val_ds` respectivamente) usando un tamaño de 224 por 224, para que sea compatible con VGG16:

# %%
batch_size = 32
img_height = 224
img_width = 224

train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %% [markdown]
# Revisemos las dimensiones en cada uno de los conjuntos de datos:

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 224, 224, 3)
# (32,)

# %% [markdown]
# Por último, antes de usar los datos, los escalamos para que estén en el rango [0,1], y no tengamos problemas en el entrenamiento:

# %%
from tensorflow.keras import layers

scale_layer = tf.keras.layers.Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (scale_layer(x), y))
val_ds = val_ds.map(lambda x, y: (scale_layer(x), y))

# %% [markdown]
# Con estos elementos ya es posible entrenar el modelo usando "model.fit". _Nota:_ El "warning" referente al uso de funciones `lambda` no representa un problema ni afecta la ejecución del código y será eliminado en próximas versiones de Tensorflow.
#
# A continuación, se entrenará el modelo compilado. Dicho entrenamiento toma alrededor de 3 horas en el kernel de Coursera, por lo que se recomienda ejecutar todo el código de una sola vez en la opción "Cell -> Run All" para evitar que el kernel se cierre por largo tiempo de ejecución.

# %%
epochs = 10
model_train = model.fit(train_ds,epochs=epochs,verbose=1,validation_data=val_ds)
# Out:
# Epoch 1/10
# 92/92 [==============================] - 271s 3s/step - loss: 0.9403 - accuracy: 0.6495 - val_loss: 0.6554 - val_accuracy: 0.7684
# Epoch 2/10
# 92/92 [==============================] - 278s 3s/step - loss: 0.5722 - accuracy: 0.8065 - val_loss: 0.6012 - val_accuracy: 0.7738
# Epoch 3/10
# 92/92 [==============================] - 254s 3s/step - loss: 0.5239 - accuracy: 0.8127 - val_loss: 0.5336 - val_accuracy: 0.7929
# Epoch 4/10
# 92/92 [==============================] - 232s 3s/step - loss: 0.4350 - accuracy: 0.8420 - val_loss: 0.4899 - val_accuracy: 0.8202
# Epoch 5/10
# 92/92 [==============================] - 231s 3s/step - loss: 0.4228 - accuracy: 0.8481 - val_loss: 0.5008 - val_accuracy: 0.8256
# Epoch 6/10
# 92/92 [==============================] - 242s 3s/step - loss: 0.3955 - accuracy: 0.8549 - val_loss: 0.4938 - val_accuracy: 0.8120
# Epoch 7/10
# ...

# %%
accuracy = model_train.history['accuracy']
val_accuracy = model_train.history['val_accuracy']
loss = model_train.history['loss']
val_loss = model_train.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ***
# ### B. Laboratorio Sumativo _Transfer Learning_
#
# El laboratorio consiste en hacer _transfer learning_ usando los datos de flores que se cargaron y con la partición que se hizo para entrenamiento y validación. Sin embargo, en lugar de usar la red VGG16, usaremos la red Inception, la cual también está disponible en Keras (https://keras.io/api/applications/inceptionv3/). *Nota:* Tenga en cuenta que, debido a que la implementación de estos algoritmos toma varias horas, es muy probable que el kernel de Coursera se reinicie durante la corrida de alguno de los siguientes puntos. Por lo tanto, se recomienda ejecutar este notebook en un computador local o en Google Colab.

# %% [markdown]
# #### 1. Adaptación de la red InceptionV3 para _transfer learning_ [30 puntos]
#
# Acá, debe preparar la red InceptionV3 para _transfer learning_. Para ello, debe remover las capas finales (completamente conectadas) usando la opción `top=False`.
#
# Además, después de usar "global pooling" para linealizar los datos, agregará una capa adicional completamente conectada con el número de nodos que considere adecuado (hiper-parámetro de calibración). Por último, debe agregar la capa de salida para el problema. No olvide que los parámetros anteriores a las últimas capas no son entrenables.

# %% [markdown]
# ##### Modelo 256 Neuronas

# %%
from tensorflow.keras.applications import InceptionV3
incv3 = InceptionV3(input_shape=(224,224,3), weights='imagenet', include_top=False)

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

base_incv3=GlobalAveragePooling2D()(incv3.output)

new_incv3_256=Dense(256,activation='relu')(base_incv3) 

out_layer_incv3=Dense(5,activation='softmax')(new_incv3_256)

for layer in incv3.layers:
    layer.trainable = False

new_incv3_256 =Model(inputs=incv3.input,outputs=out_layer_incv3)

new_incv3_256.compile(optimizer= Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.995), loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# %%
epochs = 10
model_train_256 = new_incv3_256.fit(train_ds,epochs=epochs,verbose=1,validation_data=val_ds)
# Out:
# Epoch 1/10
# 92/92 [==============================] - 81s 829ms/step - loss: 0.9813 - accuracy: 0.7296 - val_loss: 0.4214 - val_accuracy: 0.8501
# Epoch 2/10
# 92/92 [==============================] - 66s 711ms/step - loss: 0.3698 - accuracy: 0.8617 - val_loss: 0.3923 - val_accuracy: 0.8610
# Epoch 3/10
# 92/92 [==============================] - 61s 657ms/step - loss: 0.2801 - accuracy: 0.8968 - val_loss: 0.4116 - val_accuracy: 0.8597
# Epoch 4/10
# 92/92 [==============================] - 59s 641ms/step - loss: 0.2019 - accuracy: 0.9257 - val_loss: 0.3422 - val_accuracy: 0.8774
# Epoch 5/10
# 92/92 [==============================] - 59s 639ms/step - loss: 0.1545 - accuracy: 0.9421 - val_loss: 0.4864 - val_accuracy: 0.8597
# Epoch 6/10
# 92/92 [==============================] - 57s 624ms/step - loss: 0.1426 - accuracy: 0.9431 - val_loss: 0.6165 - val_accuracy: 0.8365
# Epoch 7/10
# ...

# %%
plot_history(model_train_256)
# Out:
# Train Loss final: 0.079, Train Accuracy final: 0.969
# Validation Loss final: 0.670, Validation Accuracy final: 0.845

# %%
import pandas as pd
# model_256_history_df = pd.DataFrame(model_train_256.history)
# model_256_history_df.to_csv("./ModelosGuardados/model_256_history.csv", index=False)
# new_incv3_256.save("./ModelosGuardados/model_256.keras")

# %% [markdown]
# ##### Modelo 128 Neuronas

# %%
from tensorflow.keras.applications import InceptionV3
incv3 = InceptionV3(input_shape=(224,224,3), weights='imagenet', include_top=False)
incv3.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_94 (Conv2D)          (None, 111, 111, 32)         864       ['input_3[0][0]']
#
#  batch_normalization_94 (Ba  (None, 111, 111, 32)         96        ['conv2d_94[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 111, 111, 32)         0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_95 (Conv2D)          (None, 109, 109, 32)         9216      ['activation_94[0][0]']
#
#  batch_normalization_95 (Ba  (None, 109, 109, 32)         96        ['conv2d_95[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 109, 109, 32)         0         ['batch_normalization_95[0][0]
# ...

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

base_incv3=GlobalAveragePooling2D()(incv3.output)

# %%
new_incv3_128=Dense(128,activation='relu')(base_incv3) # el enunciado dice 256 pero se implementa 128

# %%
out_layer_incv3=Dense(5,activation='softmax')(new_incv3_128)

# %%
for layer in incv3.layers:
    layer.trainable = False

# %%
new_incv3_128 =Model(inputs=incv3.input,outputs=out_layer_incv3)

# %%
new_incv3_128.compile(optimizer= Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.995), loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# %%
epochs = 10
model_train_128 = new_incv3_128.fit(train_ds,epochs=epochs,verbose=1,validation_data=val_ds)
# Out:
# Epoch 1/10
# 92/92 [==============================] - 64s 670ms/step - loss: 1.1215 - accuracy: 0.7323 - val_loss: 0.3954 - val_accuracy: 0.8583
# Epoch 2/10
# 92/92 [==============================] - 60s 649ms/step - loss: 0.3715 - accuracy: 0.8685 - val_loss: 0.4375 - val_accuracy: 0.8488
# Epoch 3/10
# 92/92 [==============================] - 59s 643ms/step - loss: 0.2621 - accuracy: 0.9046 - val_loss: 0.4864 - val_accuracy: 0.8447
# Epoch 4/10
# 92/92 [==============================] - 57s 620ms/step - loss: 0.2085 - accuracy: 0.9298 - val_loss: 0.4128 - val_accuracy: 0.8692
# Epoch 5/10
# 92/92 [==============================] - 57s 624ms/step - loss: 0.2122 - accuracy: 0.9193 - val_loss: 0.4780 - val_accuracy: 0.8474
# Epoch 6/10
# 92/92 [==============================] - 59s 636ms/step - loss: 0.1570 - accuracy: 0.9414 - val_loss: 0.5015 - val_accuracy: 0.8597
# Epoch 7/10
# ...

# %%
import pandas as pd
# model_128_history_df = pd.DataFrame(model_train_128.history)
# model_128_history_df.to_csv("./ModelosGuardados/model_128_history.csv", index=False)
# new_incv3_128.save("./ModelosGuardados/model_128.keras")

# %%
plot_history(model_train_128)
# Out:
# Train Loss final: 0.072, Train Accuracy final: 0.973
# Validation Loss final: 0.686, Validation Accuracy final: 0.856

# %% [markdown]
# ##### Modelo 64 Neuronas

# %%
incv3_64 = InceptionV3(input_shape=(224,224,3), weights='imagenet', include_top=False)

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
base_incv3_64=GlobalAveragePooling2D()(incv3_64.output)

new_incv3_64=Dense(64,activation='relu')(base_incv3_64) 

out_layer_incv3_64=Dense(5,activation='softmax')(new_incv3_64)


for layer in incv3_64.layers:
    layer.trainable = False


from tensorflow.keras.models import Model
model_incv3_64 =Model(inputs=incv3_64.input,outputs=out_layer_incv3_64)

from keras.optimizers import Adam
model_incv3_64.compile(optimizer= Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.995), loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# %%
epochs = 10
model_incv3_64_train = model_incv3_64.fit(train_ds,epochs=epochs,verbose=1,validation_data=val_ds)
# Out:
# Epoch 1/10
# 92/92 [==============================] - 60s 624ms/step - loss: 0.7635 - accuracy: 0.7360 - val_loss: 0.4152 - val_accuracy: 0.8678
# Epoch 2/10
# 92/92 [==============================] - 57s 613ms/step - loss: 0.3546 - accuracy: 0.8719 - val_loss: 0.4643 - val_accuracy: 0.8406
# Epoch 3/10
# 92/92 [==============================] - 56s 612ms/step - loss: 0.2835 - accuracy: 0.8941 - val_loss: 0.4717 - val_accuracy: 0.8501
# Epoch 4/10
# 92/92 [==============================] - 58s 623ms/step - loss: 0.2525 - accuracy: 0.9162 - val_loss: 0.3872 - val_accuracy: 0.8638
# Epoch 5/10
# 92/92 [==============================] - 56s 609ms/step - loss: 0.1795 - accuracy: 0.9319 - val_loss: 0.4127 - val_accuracy: 0.8556
# Epoch 6/10
# 92/92 [==============================] - 57s 622ms/step - loss: 0.1784 - accuracy: 0.9288 - val_loss: 0.4339 - val_accuracy: 0.8638
# Epoch 7/10
# ...

# %%
plot_history(model_incv3_64_train)
# Out:
# Train Loss final: 0.111, Train Accuracy final: 0.958
# Validation Loss final: 0.563, Validation Accuracy final: 0.853

# %%
import pandas as pd
# incv3_64_history_df = pd.DataFrame(model_incv3_64_train.history)
# incv3_64_history_df.to_csv("incv3_64_history.csv", index=False)
# model_incv3_64.save("incv3_64_tr_model.keras")

# %% [markdown]
# ##### Modelo 32 Neuronas

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

incv3_32= InceptionV3(input_shape=(224,224,3), weights='imagenet', include_top=False)

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
base_incv3_32=GlobalAveragePooling2D()(incv3_32.output)


new_incv3_32=Dense(16,activation='relu')(base_incv3_32) 

out_layer_incv3_32=Dense(5,activation='softmax')(new_incv3_32)

for layer in incv3_32.layers:
    layer.trainable = False

from tensorflow.keras.models import Model
model_incv3_32 =Model(inputs=incv3_32.input,outputs=out_layer_incv3_32)


from keras.optimizers import Adam
model_incv3_32.compile(optimizer= Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.995), loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# %%
epochs = 10
model_incv3_32_train = model_incv3_32.fit(train_ds,epochs=epochs,verbose=1,validation_data=val_ds)
# Out:
# Epoch 1/10
# 92/92 [==============================] - 61s 631ms/step - loss: 0.8221 - accuracy: 0.7061 - val_loss: 0.5304 - val_accuracy: 0.8134
# Epoch 2/10
# 92/92 [==============================] - 59s 644ms/step - loss: 0.4209 - accuracy: 0.8525 - val_loss: 0.4054 - val_accuracy: 0.8651
# Epoch 3/10
# 92/92 [==============================] - 57s 621ms/step - loss: 0.2980 - accuracy: 0.8944 - val_loss: 0.3679 - val_accuracy: 0.8719
# Epoch 4/10
# 92/92 [==============================] - 58s 632ms/step - loss: 0.2737 - accuracy: 0.9057 - val_loss: 0.4288 - val_accuracy: 0.8597
# Epoch 5/10
# 92/92 [==============================] - 58s 630ms/step - loss: 0.1831 - accuracy: 0.9387 - val_loss: 0.3813 - val_accuracy: 0.8747
# Epoch 6/10
# 92/92 [==============================] - 58s 635ms/step - loss: 0.1301 - accuracy: 0.9574 - val_loss: 0.5036 - val_accuracy: 0.8365
# Epoch 7/10
# ...

# %%
plot_history(model_incv3_32_train)
# Out:
# Train Loss final: 0.119, Train Accuracy final: 0.956
# Validation Loss final: 0.473, Validation Accuracy final: 0.883

# %%
import pandas as pd
# incv3_32_history_df = pd.DataFrame(model_incv3_32_train.history)
# incv3_32_history_df.to_csv("incv3_32_history.csv", index=False)
# model_incv3_32.save("incv3_32_model.keras")

# %% [markdown]
# ##### Modelo 16 Neuronas

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

incv3_16= InceptionV3(input_shape=(224,224,3), weights='imagenet', include_top=False)

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
base_incv3_16=GlobalAveragePooling2D()(incv3_16.output)


new_incv3_16=Dense(16,activation='relu')(base_incv3_16) 

out_layer_incv3_16=Dense(5,activation='softmax')(new_incv3_16)

for layer in incv3_16.layers:
    layer.trainable = False

from tensorflow.keras.models import Model
model_incv3_16 =Model(inputs=incv3_16.input,outputs=out_layer_incv3_16)


from keras.optimizers import Adam
model_incv3_16.compile(optimizer= Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.995), loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# %%
epochs = 10
model_incv3_16_train = model_incv3_16.fit(train_ds,epochs=epochs,verbose=1,validation_data=val_ds)
# Out:
# Epoch 1/10
# 92/92 [==============================] - 59s 617ms/step - loss: 1.3141 - accuracy: 0.4152 - val_loss: 0.9649 - val_accuracy: 0.5899
# Epoch 2/10
# 92/92 [==============================] - 58s 626ms/step - loss: 0.8458 - accuracy: 0.6570 - val_loss: 0.7921 - val_accuracy: 0.6826
# Epoch 3/10
# 92/92 [==============================] - 57s 617ms/step - loss: 0.7456 - accuracy: 0.6931 - val_loss: 0.7149 - val_accuracy: 0.7221
# Epoch 4/10
# 92/92 [==============================] - 57s 624ms/step - loss: 0.6636 - accuracy: 0.7251 - val_loss: 0.7214 - val_accuracy: 0.7316
# Epoch 5/10
# 92/92 [==============================] - 59s 637ms/step - loss: 0.6046 - accuracy: 0.7459 - val_loss: 0.6791 - val_accuracy: 0.7466
# Epoch 6/10
# 92/92 [==============================] - 57s 621ms/step - loss: 0.5498 - accuracy: 0.7725 - val_loss: 0.6744 - val_accuracy: 0.7534
# Epoch 7/10
# ...

# %%
plot_history(model_incv3_16_train)
# Out:
# Train Loss final: 0.385, Train Accuracy final: 0.868
# Validation Loss final: 0.676, Validation Accuracy final: 0.802

# %%
import pandas as pd
# incv3_16_history_df = pd.DataFrame(model_incv3_16_train.history)
# incv3_16_history_df.to_csv("incv3_16_history.csv", index=False)
# model_incv3_16.save("incv3_16_tr_model.keras")

# %% [markdown]
# ##### Comparacion modelos

# %%
models = ['modelo 256 Neuronas','modelo 128 Neuronas','modelo 64 Neuronas','modelo 32 Neuronas','modelo 16 Neuronas']
historias = [model_train_256, model_train_128, model_incv3_64_train, model_incv3_32_train, model_incv3_16_train]
accuracy_train =[]
accuracy_val = []
loss_train = []
loss_val = []

for i in historias:
    accuracy_train.append(i.history['accuracy'][-1])
    loss_train.append(i.history['loss'][-1])
    accuracy_val.append(i.history['val_accuracy'][-1])
    loss_val.append(i.history['val_loss'][-1])

# %%
import matplotlib.pyplot as plt
import numpy as np


fig, axs = plt.subplots(1, 2, figsize=(40, 15))  

x = np.arange(len(models))
width = 0.2  

# --- Loss ---
axs[0].bar(x - width/2, loss_train, width, label='Train Loss', color='#F2527D')
axs[0].bar(x + width/2, loss_val, width, label='Validacion Loss', color='#3C3A8C')
axs[0].set_title('Pérdida en Validación al final del entrenamiento por Modelo', fontsize=24)
axs[0].set_ylim(0.05, 0.75)
axs[0].set_xlabel('Modelos', fontsize=20)
axs[0].set_ylabel('Loss', fontsize=20)
axs[0].set_xticks(x)
axs[0].set_xticklabels(models, fontsize=18, rotation=45, ha='right')
axs[0].legend(fontsize=16)
axs[0].grid(True, linestyle='--', alpha=0.6)

# --- Accuracy ---
axs[1].bar(x - width/2, accuracy_train, width, label='Train accuracy', color='#F28444')
axs[1].bar(x + width/2, accuracy_val, width, label='Validacion accuracy', color='#D95BAD')
axs[1].set_title('Accuracy en Validación al final del entrenamiento por Modelo', fontsize=24)
axs[1].set_xlabel('Modelos', fontsize=20)
axs[1].set_ylabel('Accuracy', fontsize=20)
axs[1].set_xticks(x)
axs[1].set_xticklabels(models, fontsize=18, rotation=45, ha='right')
axs[1].set_ylim(0.75, 1.0)
axs[1].legend(fontsize=16)
axs[1].grid(True, linestyle='--', alpha=0.6)

for i, v in enumerate(accuracy_train):
    axs[1].text(i - 0.2, v + 0.005, f"{v:.2f}", fontsize=20)

for i, v in enumerate(accuracy_val):
    axs[1].text(i , v + 0.01, f"{v:.2f}", fontsize=20)

for i, v in enumerate(loss_val):
    axs[0].text(i + 0.05, v + 0.005, f"{v:.2f}", fontsize=20)
   
for i, v in enumerate(loss_train):
    axs[0].text(i - 0.2, v + 0.01, f"{v:.2f}", fontsize=20)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Se puede ver entonces que el mejor modelo es el de 32 neuronas si lo vemos con validation loss. Y el modelo de 128 si lo vemos con train accuracy. Vemos entonces que tener mas neuronas no significa tener un mejor modelo

# %% [markdown]
# #### 2. Estimación del modelo propuesto y calibración de gradiente descendiente [20 puntos]
# Usando el modelo propuesto, estime los parámetros asociados. No olvide calibrar el modelo con los algoritmos de estimación correspondiente. También puede considerar un capa de _dropout_ antes de la capa de salida.

# %% [markdown]
# ##### Modelo 128 Neuronas

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
incv3_32_tn2 = InceptionV3(input_shape=(224,224,3), weights='imagenet', include_top=False)

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
base_incv3_32_tn2=GlobalAveragePooling2D()(incv3_32_tn2.output)

new_incv3_32_tn2=Dense(32,activation='relu')(base_incv3_32_tn2) 

# Añadimos una capa de dropout
from tensorflow.keras.layers import Dropout
incv3_32_tn2_dp = Dropout(0.25)(new_incv3_32_tn2)

out_layer_incv3_32_tn2=Dense(5,activation='softmax')(incv3_32_tn2_dp)

for layer in incv3_32_tn2.layers:
    layer.trainable = False

from tensorflow.keras.models import Model
model_incv3_32_tn2 =Model(inputs=incv3_32_tn2.input,outputs=out_layer_incv3_32_tn2)

from keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.995) # learning rate = 0.001 en lugar de 0.005 

lr_callback = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

model_incv3_32_tn2.compile(optimizer= optimizer, loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# %%
epochs = 10
model_incv3_32_tn2_train = model_incv3_32_tn2.fit(train_ds,epochs=epochs,verbose=1,validation_data=val_ds,
    callbacks=[lr_callback])
# Out:
# Epoch 1/10
# 92/92 [==============================] - 67s 694ms/step - loss: 0.8413 - accuracy: 0.6686 - val_loss: 0.4945 - val_accuracy: 0.8297 - lr: 0.0010
# Epoch 2/10
# 92/92 [==============================] - 61s 663ms/step - loss: 0.5111 - accuracy: 0.8151 - val_loss: 0.4188 - val_accuracy: 0.8542 - lr: 0.0010
# Epoch 3/10
# 92/92 [==============================] - 58s 631ms/step - loss: 0.4164 - accuracy: 0.8505 - val_loss: 0.3634 - val_accuracy: 0.8856 - lr: 0.0010
# Epoch 4/10
# 92/92 [==============================] - 60s 650ms/step - loss: 0.3579 - accuracy: 0.8675 - val_loss: 0.3522 - val_accuracy: 0.8869 - lr: 0.0010
# Epoch 5/10
# 92/92 [==============================] - 59s 637ms/step - loss: 0.3089 - accuracy: 0.8896 - val_loss: 0.3602 - val_accuracy: 0.8760 - lr: 0.0010
# Epoch 6/10
# 92/92 [==============================] - ETA: 0s - loss: 0.2769 - accuracy: 0.8992
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# ...

# %%
plot_history(model_incv3_32_tn2_train)
# Out:
# Train Loss final: 0.166, Train Accuracy final: 0.947
# Validation Loss final: 0.333, Validation Accuracy final: 0.891

# %% [markdown]
# ##### Modelo 32 Neuronas

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
incv3_128_tn2 = InceptionV3(input_shape=(224,224,3), weights='imagenet', include_top=False)

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
base_incv3_128_tn2=GlobalAveragePooling2D()(incv3_128_tn2.output)

new_incv3_128_tn2=Dense(128,activation='relu')(base_incv3_128_tn2) 

# Añadimos una capa de dropout
from tensorflow.keras.layers import Dropout
incv3_128_tn2_dp = Dropout(0.25)(new_incv3_128_tn2)

out_layer_incv3_128_tn2=Dense(5,activation='softmax')(incv3_128_tn2_dp)

for layer in incv3_128_tn2.layers:
    layer.trainable = False

from tensorflow.keras.models import Model
model_incv3_128_tn2 =Model(inputs=incv3_128_tn2.input,outputs=out_layer_incv3_128_tn2)

from keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.995) # learning rate = 0.001 en lugar de 0.005 

lr_callback = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

model_incv3_128_tn2.compile(optimizer= optimizer, loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# %%
epochs = 10
model_incv3_128_tn2_train = model_incv3_128_tn2.fit(train_ds,epochs=epochs,verbose=1,validation_data=val_ds,
    callbacks=[lr_callback])
# Out:
# Epoch 1/10
# 92/92 [==============================] - 60s 617ms/step - loss: 0.7531 - accuracy: 0.7180 - val_loss: 0.4251 - val_accuracy: 0.8624 - lr: 0.0010
# Epoch 2/10
# 92/92 [==============================] - 57s 615ms/step - loss: 0.4240 - accuracy: 0.8512 - val_loss: 0.3681 - val_accuracy: 0.8706 - lr: 0.0010
# Epoch 3/10
# 92/92 [==============================] - 56s 608ms/step - loss: 0.3143 - accuracy: 0.8818 - val_loss: 0.3479 - val_accuracy: 0.8760 - lr: 0.0010
# Epoch 4/10
# 92/92 [==============================] - 62s 675ms/step - loss: 0.2740 - accuracy: 0.9063 - val_loss: 0.3496 - val_accuracy: 0.8665 - lr: 0.0010
# Epoch 5/10
# 92/92 [==============================] - ETA: 0s - loss: 0.2262 - accuracy: 0.9186
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 92/92 [==============================] - 58s 633ms/step - loss: 0.2262 - accuracy: 0.9186 - val_loss: 0.3510 - val_accuracy: 0.8706 - lr: 0.0010
# Epoch 6/10
# ...

# %%
plot_history(model_incv3_128_tn2_train)
# Out:
# Train Loss final: 0.089, Train Accuracy final: 0.977
# Validation Loss final: 0.326, Validation Accuracy final: 0.879

# %%
import pandas as pd
# incv3_128_tn2_history_df = pd.DataFrame(model_incv3_128_tn2_train.history)
# incv3_128_tn2_history_df.to_csv("./ModelosGuardados/incv3_128_tn2_history.csv", index=False)
# model_incv3_128_tn2.save("./ModelosGuardados/incv3_128_tn2_tr_model.keras")

# %% [markdown]
# ##### Comparacion Modelos

# %%
models = ['modelo 128 Neuronas Calibrado','modelo 32 Neuronas']
historias = [model_incv3_128_tn2_train, model_incv3_32_tn2_train]
accuracy_train =[]
accuracy_val = []
loss_train = []
loss_val = []

for i in historias:
    accuracy_train.append(i.history['accuracy'][-1])
    loss_train.append(i.history['loss'][-1])
    accuracy_val.append(i.history['val_accuracy'][-1])
    loss_val.append(i.history['val_loss'][-1])

# %%
import matplotlib.pyplot as plt
import numpy as np


fig, axs = plt.subplots(1, 2, figsize=(40, 15))  

x = np.arange(len(models))
width = 0.2  

# --- Loss ---
axs[0].bar(x - width/2, loss_train, width, label='Train Loss', color='#F2527D')
axs[0].bar(x + width/2, loss_val, width, label='Validacion Loss', color='#3C3A8C')
axs[0].set_title('Pérdida en Validación al final del entrenamiento por Modelo', fontsize=24)
axs[0].set_ylim(0.05, 0.75)
axs[0].set_xlabel('Modelos', fontsize=20)
axs[0].set_ylabel('Loss', fontsize=20)
axs[0].set_xticks(x)
axs[0].set_xticklabels(models, fontsize=18, rotation=45, ha='right')
axs[0].legend(fontsize=16)
axs[0].grid(True, linestyle='--', alpha=0.6)

# --- Accuracy ---
axs[1].bar(x - width/2, accuracy_train, width, label='Train accuracy', color='#F28444')
axs[1].bar(x + width/2, accuracy_val, width, label='Validacion accuracy', color='#D95BAD')
axs[1].set_title('Accuracy en Validación al final del entrenamiento por Modelo', fontsize=24)
axs[1].set_xlabel('Modelos', fontsize=20)
axs[1].set_ylabel('Accuracy', fontsize=20)
axs[1].set_xticks(x)
axs[1].set_xticklabels(models, fontsize=18, rotation=45, ha='right')
axs[1].set_ylim(0.75, 1.0)
axs[1].legend(fontsize=16)
axs[1].grid(True, linestyle='--', alpha=0.6)

for i, v in enumerate(accuracy_train):
    axs[1].text(i - 0.2, v + 0.005, f"{v:.2f}", fontsize=20)

for i, v in enumerate(accuracy_val):
    axs[1].text(i , v + 0.01, f"{v:.2f}", fontsize=20)

for i, v in enumerate(loss_val):
    axs[0].text(i + 0.05, v + 0.005, f"{v:.2f}", fontsize=20)
   
for i, v in enumerate(loss_train):
    axs[0].text(i - 0.2, v + 0.01, f"{v:.2f}", fontsize=20)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Como se puede ver

# %% [markdown]
# #### 3. Comparación con modelos VGG16 sin _transfer learning_ [20 puntos]
# Para revisar si hacer _transfer learning_ tiene alguna utilidad en el modelo, ahora deberá estimar todos los parámetros de la red VGG16 (con todos los parámetros estimables), tenga en cuenta que esto puede tardar bastante. Compare los resultados en la muestra de validación.

# %%
vgg_full = VGG16(input_shape=(224,224,3), weights=None, include_top=False)

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

base_full=GlobalAveragePooling2D()(vgg_full.output)

# %%
new_full=Dense(128,activation='relu')(base_full)

# %%
out_layer_full=Dense(5,activation='softmax')(new_full)

# %%
# Aqui hacemos todos los parámetros estimables
for layer in vgg_full.layers:
    layer.trainable = True

# %%
from tensorflow.keras.models import Model

model_full=Model(inputs=vgg_full.input,outputs=out_layer_full)

# %%
from keras.optimizers import Adam
model_full.compile(optimizer= Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.995), loss='SparseCategoricalCrossentropy', metrics=['accuracy'])

# %%
epochs = 10
model_full_train = model_full.fit(train_ds,epochs=epochs,verbose=1,validation_data=val_ds)
# Out:
# Epoch 1/10
# 92/92 [==============================] - 883s 10s/step - loss: 16986.5293 - accuracy: 0.2214 - val_loss: 1.6032 - val_accuracy: 0.2398
# Epoch 2/10
# 92/92 [==============================] - 847s 9s/step - loss: 1.6020 - accuracy: 0.2459 - val_loss: 1.6030 - val_accuracy: 0.2398
# Epoch 3/10
# 92/92 [==============================] - 859s 9s/step - loss: 1.6015 - accuracy: 0.2459 - val_loss: 1.6024 - val_accuracy: 0.2398
# Epoch 4/10
# 92/92 [==============================] - 849s 9s/step - loss: 1.6017 - accuracy: 0.2459 - val_loss: 1.6023 - val_accuracy: 0.2398
# Epoch 5/10
# 92/92 [==============================] - 917s 10s/step - loss: 1.6010 - accuracy: 0.2459 - val_loss: 1.6020 - val_accuracy: 0.2398
# Epoch 6/10
# 92/92 [==============================] - 889s 10s/step - loss: 1.6011 - accuracy: 0.2459 - val_loss: 1.6019 - val_accuracy: 0.2398
# Epoch 7/10
# ...

# %%
plot_history(model_full_train)
# Out:
# Train Loss final: 1.601, Train Accuracy final: 0.246
# Validation Loss final: 1.602, Validation Accuracy final: 0.240

# %%
import pandas as pd
vgg16_full_history_df = pd.DataFrame(model_full_train.history)
vgg16_full_history_df.to_csv("./ModelosGuardados/vgg16_full_history.csv", index=False)
model_full.save("./ModelosGuardados/vgg16_full_tr_model.keras")

# %% [markdown]
# #### 4. _Transfer learning_ con reuso de parámetros (_fine tunning_) [30 puntos]
# En la práctica es común que después de hacer _transfer learning_, los parámetros de la red, o de algunas de las últimas capas que no se habían entrenado se liberan para que sean entrenadas.
#
# Acá, debe tomar la red que estimó en el punto 1 por _transfer learning_ y la solución la debe tomar como los valores iniciales de una nueva red, en la cual simplemente se dejan entrenables las dos últimas capas de InceptionV3 que se habían dejado no entrenables.
#
# Compare los resultados con los modelos anteriores.

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam


incv3 = InceptionV3(input_shape=(224,224,3), weights='imagenet', include_top=False)

# Congelar todas las capas primero
for layer in incv3.layers:
    layer.trainable = False

# Descongelar las últimas dos capas del modelo base
for layer in incv3.layers[-2:]:
    layer.trainable = True


base_incv3_ft = GlobalAveragePooling2D()(incv3.output)
new_incv3_ft = Dense(32, activation='relu')(base_incv3_ft)
out_layer_incv3 = Dense(5, activation='softmax')(new_incv3_ft)


new_incv3_ft = Model(inputs=incv3.input, outputs=out_layer_incv3)


new_incv3_ft.compile(
    optimizer=Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.995),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
epochs = 10
model_train_ft = new_incv3_ft.fit(train_ds,epochs=epochs,verbose=1,validation_data=val_ds)
# Out:
# Epoch 1/10
# 92/92 [==============================] - 64s 669ms/step - loss: 0.7728 - accuracy: 0.7401 - val_loss: 0.4730 - val_accuracy: 0.8406
# Epoch 2/10
# 92/92 [==============================] - 64s 698ms/step - loss: 0.3641 - accuracy: 0.8696 - val_loss: 0.4336 - val_accuracy: 0.8488
# Epoch 3/10
# 92/92 [==============================] - 61s 659ms/step - loss: 0.2576 - accuracy: 0.9074 - val_loss: 0.4033 - val_accuracy: 0.8583
# Epoch 4/10
# 92/92 [==============================] - 61s 663ms/step - loss: 0.2381 - accuracy: 0.9118 - val_loss: 0.3814 - val_accuracy: 0.8678
# Epoch 5/10
# 92/92 [==============================] - 61s 657ms/step - loss: 0.1888 - accuracy: 0.9322 - val_loss: 0.4187 - val_accuracy: 0.8665
# Epoch 6/10
# 92/92 [==============================] - 62s 668ms/step - loss: 0.1411 - accuracy: 0.9513 - val_loss: 0.4165 - val_accuracy: 0.8610
# Epoch 7/10
# ...

# %%
plot_history(model_train_ft)
# Out:
# Train Loss final: 0.069, Train Accuracy final: 0.976
# Validation Loss final: 0.560, Validation Accuracy final: 0.864

# %% [markdown]
# El modelo con fine tuning, es decir con 2 capas que van a ser entrenadas, partio del mejor modelo es decir el que tenia 32 neuronas. Este modelo resulto en
